# %%
import pandas as pd
import numpy as np


import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
df=pd.read_csv(r'F:\dm\1 - Copy\master.csv')
print (df)
# Out:
#       Year Area affected Population affected Damage to Crops(area)  \
# 0     1953           Nil                 Nil                   Nil
# 1     1954           Nil                 Nil                   Nil
# 2     1955           Nil                 Nil                   Nil
# 3     1956           Nil                 Nil                   Nil
# 4     1957           Nil                 Nil                   Nil
# ...    ...           ...                 ...                   ...
# 2235  2012             0               0.529                 0.012
# 2236  2013         0.182               3.112                 0.182
# 2237  2014         0.051               0.448                 0.051
# 2238  2015           1.3               10.84                   1.3
# 2239  2016           NaN                 NaN                   NaN
#
#      Damage to Crops(value) Damage to Houses(number) Damage to Houses(value)  \
# 0                       Nil                      Nil                     Nil
# ...

# %%
df.describe(include='all')
# Out:
#                Year Area affected Population affected Damage to Crops(area)  \
# count   2240.000000          2199                2208                  2207
# unique          NaN           359                 548                   306
# top             NaN           Nil                 Nil                   Nil
# freq            NaN           635                 699                   659
# mean    1984.500000           NaN                 NaN                   NaN
# std       18.477078           NaN                 NaN                   NaN
# min     1953.000000           NaN                 NaN                   NaN
# 25%     1968.750000           NaN                 NaN                   NaN
# 50%     1984.500000           NaN                 NaN                   NaN
# 75%     2000.250000           NaN                 NaN                   NaN
# max     2016.000000           NaN                 NaN                   NaN
#
# ...

# %%
df.isnull().sum()
# Out:
# Year                                        0
# Area affected                              41
# Population affected                        32
# Damage to Crops(area)                      33
# Damage to Crops(value)                     42
# Damage to Houses(number)                   26
# Damage to Houses(value)                    44
# Cattle lost(number)                        33
# Human lives lost(number)                   25
# Damage to public utilities                 36
# Damage to crops,houses,public utilities     3
# Place                                       0
# dtype: int64

# %%
df.dtypes
# Out:
# Year                                        int64
# Area affected                              object
# Population affected                        object
# Damage to Crops(area)                      object
# Damage to Crops(value)                     object
# Damage to Houses(number)                   object
# Damage to Houses(value)                    object
# Cattle lost(number)                        object
# Human lives lost(number)                   object
# Damage to public utilities                 object
# Damage to crops,houses,public utilities    object
# Place                                      object
# dtype: object

# %%
temp = pd.DataFrame(index=df.columns)
temp['data_type'] = df.dtypes
temp['null_count'] = df.isnull().sum()
temp['unique_count'] = df.nunique()

# %%
temp
# Out:
#                                         data_type  null_count  unique_count
# Year                                        int64           0            64
# Area affected                              object          41           359
# Population affected                        object          32           548
# Damage to Crops(area)                      object          33           306
# Damage to Crops(value)                     object          42           797
# Damage to Houses(number)                   object          26           989
# Damage to Houses(value)                    object          44           650
# Cattle lost(number)                        object          33           640
# Human lives lost(number)                   object          25           271
# Damage to public utilities                 object          36           717
# Damage to crops,houses,public utilities    object           3           952
# ...

# %%
import pandas as pd
df1=pd.read_csv(r'F:\dm\1 - Copy\Andaman Nicobar.csv')
print (df1)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL          0.03               0.042                  0.03
# 65      NaN  Average         0.001               0.002                 0.001
# 66      NaN  Maximum          0.03                0.04                  0.03
# 67      NaN   (Year)          1988                1988                  1988
#
# ...

# %%
import pandas as pd
df2=pd.read_csv(r'F:\dm\1 - Copy\Andhra Pradesh.csv')
print (df2)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953          0.07                2.66                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Neg                 Nil                  0.19
# 3       4.0     1956          1.39                 0.2                  0.05
# 4       5.0     1957          0.01                 Nil                  0.01
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016         0.003               0.386                 0.003
# 64      NaN    Total        23.249             122.917                17.129
# 65      NaN  Average         0.517               2.998                 0.343
# 66      NaN  Maximum          9.04               13.42                 1.995
# 67      NaN   (Year)         -2005               -1969                 -2010
#
# ...

# %%
import pandas as pd
df3=pd.read_csv(r'F:\dm\1 - Copy\Arunachal Pradesh.csv')
print (df3)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL         1.447               14.11                  0.66
# 65      NaN  Average         0.063               0.487                  0.03
# 66      NaN  Maximum          0.31                 4.5                  0.31
# 67      NaN   (Year)          2013                2010                 -2013
#
# ...

# %%
import pandas as pd
df4=pd.read_csv(r'F:\dm\1 - Copy\Assam.csv')
print (df4)
# Out:
#     Sl. No.     Year  Area affected  Population affected  \
# 0       1.0     1953          0.080                0.410
# 1       2.0     1954          3.150                1.680
# 2       3.0     1955          1.410                0.800
# 3       4.0     1956          0.600                0.560
# 4       5.0     1957          0.400                0.310
# ..      ...      ...            ...                  ...
# 63     64.0     2016          0.000                0.003
# 64      NaN    TOTAL         51.564              166.313
# 65      NaN  Average          0.806                2.599
# 66      NaN  Maximum          3.820               12.637
# 67      NaN   (Year)      -1988.000            -2004.000
#
#    Damage to Crops(area)  Damage to Crops(value) Damage to Houses(number)  \
# 0                    Neg                   2.120                      Neg
# 1                   0.27                  10.620                      Nil
# ...

# %%
import pandas as pd
df5=pd.read_csv(r'F:\dm\1 - Copy\Bihar.csv')
print (df5)
# Out:
#     Sl. No.     Year  Area affected  Population affected  \
# 0       1.0     1953          0.970                6.770
# 1       2.0     1954          2.500                7.670
# 2       3.0     1955          1.770                7.110
# 3       4.0     1956          1.320                3.120
# 4       5.0     1957          0.790                1.730
# ..      ...      ...            ...                  ...
# 63     64.0     2016          0.410                8.823
# 64      NaN    TOTAL         81.694              404.077
# 65      NaN  Average          1.297                6.314
# 66      NaN  Maximum          4.260               29.985
# 67      NaN   (Year)      -1971.000             2004.000
#
#    Damage to Crops(area) Damage to Crops(value)  Damage to Houses(number)  \
# 0                   0.93                     29                    184300
# 1                   1.59                     15                    179451
# ...

# %%
import pandas as pd
df6=pd.read_csv(r'F:\dm\1 - Copy\Chandigarh.csv')
print (df6)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           Nil                 Nil                   Nil
# 64      NaN    TOTAL             0                   0                     0
# 65      NaN  Average             0                   0                     0
# 66      NaN  Maximum             0                   0                     0
# 67      NaN   (Year)         -2004               -2004                 -2004
#
# ...

# %%
import pandas as pd
df7=pd.read_csv(r'F:\dm\1 - Copy\Chattisgarh.csv')
print (df7)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953          0.26                0.05                   Neg
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955          0.03                 Neg                   Nil
# 3       4.0     1956          0.04                0.02                   Nil
# 4       5.0     1957          0.03                 Nil                  0.02
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL         0.161               2.249                 0.149
# 65      NaN  Average         0.013               0.187                 0.012
# 66      NaN  Maximum         0.089               0.676                 0.089
# 67      NaN   (Year)         -2001               -2003                 -2001
#
# ...

# %%
import pandas as pd
df8=pd.read_csv(r'F:\dm\1 - Copy\Dadra & Nagar Haveli.csv')
print (df8)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           Nil                 Nil                   Nil
# 64      NaN    TOTAL             3                   4                     5
# 65      NaN  Average             0                   0                     0
# 66      NaN  Maximum             0                   0                     0
# 67      NaN   (Year)         -1976              (----)                 -1976
#
# ...

# %%
import pandas as pd
df9=pd.read_csv(r'F:\dm\1 - Copy\Daman & Diu.csv')
print (df9)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016             0                   0                     0
# 64      NaN    TOTAL             0                0.01                     0
# 65      NaN  Average             0               0.001                     0
# 66      NaN  Maximum             0                0.01                     0
# 67      NaN   (Year)         -2005               -2004                 -2005
#
# ...

# %%
import pandas as pd
df10=pd.read_csv(r'F:\dm\1 - Copy\Delhi.csv')
print (df10)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955          0.03                 Nil                   Neg
# 3       4.0     1956          0.01                 0.1                  0.01
# 4       5.0     1957          0.01                 Neg                   Neg
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL         0.923               3.716                 0.312
# 65      NaN  Average         0.023               0.098                 0.009
# 66      NaN  Maximum         0.458               1.854                 0.155
# 67      NaN   (Year)         -1997               -1997                 -1997
#
# ...

# %%
import pandas as pd
df11=pd.read_csv(r'F:\dm\1 - Copy\Goa.csv')
print (df11)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016             0                   0                     0
# 64      NaN    TOTAL             0               0.055                 0.007
# 65      NaN  Average             0               0.002                     0
# 66      NaN  Maximum             0               0.053                 0.004
# 67      NaN   (Year)          1974                1976                  2001
#
# ...

# %%
import pandas as pd
df12=pd.read_csv(r'F:\dm\1 - Copy\Gujarat.csv')
print (df12)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Neg
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956          0.26                0.01                   Neg
# 4       5.0     1957          0.08                0.01                   Neg
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN               0.012                   NaN
# 64      NaN    TOTAL         15.62             101.322                11.424
# 65      NaN  Average         0.355               1.809                 0.266
# 66      NaN  Maximum          2.05              16.486                  1.49
# 67      NaN   (Year)         -1988               -1996                 -1988
#
# ...

# %%
import pandas as pd
df13=pd.read_csv(r'F:\dm\1 - Copy\Haryana.csv')
print (df13)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Neg                 Nil                   Nil
# 1       2.0     1954           Neg                0.02                   Neg
# 2       3.0     1955          0.13                1.26                  0.12
# 3       4.0     1956          0.03                 Nil                  0.02
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016         0.004                   0                 0.004
# 64      NaN    TOTAL         9.285              24.999                 6.151
# 65      NaN  Average         0.193               0.521                 0.134
# 66      NaN  Maximum             1                3.04                   0.8
# 67      NaN   (Year)         -1977               -1977                 -1977
#
# ...

# %%
import pandas as pd
df14=pd.read_csv(r'F:\dm\1 - Copy\Himachal Pradesh.csv')
print (df14)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956          Neg.                 Nil                  Neg.
# 4       5.0     1957          0.23                0.09                  0.01
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016         0.035               6.865                 0.035
# 64      NaN    TOTAL         9.307              49.258                 4.502
# 65      NaN  Average         0.332               1.493                  0.15
# 66      NaN  Maximum          2.87               6.865                 0.476
# 67      NaN   (Year)         -1999               -2015                 -1994
#
# ...

# %%
import pandas as pd
df15=pd.read_csv(r'F:\dm\1 - Copy\Jammu & Kashmir.csv')
print (df15)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954          0.05                 0.1                   Neg
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957          0.05                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL         1.973               8.532                  1.79
# 65      NaN  Average         0.056               0.267                 0.058
# 66      NaN  Maximum         0.651               2.078                 0.651
# 67      NaN   (Year)          2014                1992                  2014
#
# ...

# %%
import pandas as pd
df16=pd.read_csv(r'F:\dm\1 - Copy\Jharkhand.csv')
print (df16)
# Out:
#     Sl. No.     Year  Area affected  Population affected  \
# 0       1.0     1953          0.970                6.770
# 1       2.0     1954          2.500                7.670
# 2       3.0     1955          1.770                7.110
# 3       4.0     1956          1.320                3.120
# 4       5.0     1957          0.790                1.730
# ..      ...      ...            ...                  ...
# 63     64.0     2016            NaN                  NaN
# 64      NaN    TOTAL          0.063                0.366
# 65      NaN  Average          0.005                0.026
# 66      NaN  Maximum          0.041                0.199
# 67      NaN   (Year)      -2012.000            -2013.000
#
#    Damage to Crops(area) Damage to Crops(value)  Damage to Houses(number)  \
# 0                   0.93                     29                  184300.0
# 1                   1.59                     15                  179451.0
# ...

# %%
import pandas as pd
df17=pd.read_csv(r'F:\dm\1 - Copy\Karnataka.csv')
print (df17)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Neg                 Neg                   Neg
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016          3.78                2.18                  3.78
# 64      NaN    TOTAL        11.323               34.06                10.822
# 65      NaN  Average         0.276               0.873                 0.277
# 66      NaN  Maximum          3.78                  18                  3.78
# 67      NaN   (Year)         -2016               -2009                 -2016
#
# ...

# %%
import pandas as pd
df18=pd.read_csv(r'F:\dm\1 - Copy\Kerala.csv')
print (df18)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956          0.02                0.03                   Neg
# 4       5.0     1957          0.29                0.33                  0.01
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016         0.002               0.006                 0.002
# 64      NaN    TOTAL         8.039              84.604                 2.888
# 65      NaN  Average         0.161               1.627                 0.059
# 66      NaN  Maximum          1.47                14.6                 0.578
# 67      NaN   (Year)          1989                1985                  1991
#
# ...

# %%
import pandas as pd
df19=pd.read_csv(r'F:\dm\1 - Copy\Lakshadweep.csv')
print (df19)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL             0               0.032                     0
# 65      NaN  Average             0               0.002                     0
# 66      NaN  Maximum             0               0.032                     0
# 67      NaN   (Year)         -1978                1978                 -1978
#
# ...

# %%
import pandas as pd
df20=pd.read_csv(r'F:\dm\1 - Copy\Madhya Pradesh.csv')
print (df20)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953          0.26                0.05                   Neg
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955          0.03                 Neg                   Nil
# 3       4.0     1956          0.04                0.02                   Nil
# 4       5.0     1957          0.03                 Nil                  0.02
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016         1.304                1.56                 1.304
# 64      NaN    TOTAL         8.055              42.736                 7.243
# 65      NaN  Average         0.192               0.971                 0.191
# 66      NaN  Maximum          3.67               14.72                  3.67
# 67      NaN   (Year)          2013               -2014                 -2013
#
# ...

# %%
import pandas as pd
df21=pd.read_csv(r'F:\dm\1 - Copy\Maharashtra.csv')
print (df21)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Neg                0.02                   Neg
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016         0.015               0.077                 0.015
# 64      NaN    TOTAL         2.444              14.994                 2.254
# 65      NaN  Average         0.054                 0.3                  0.05
# 66      NaN  Maximum         0.391                4.17                 0.391
# 67      NaN   (Year)         -2002               -1984                 -2002
#
# ...

# %%
import pandas as pd
df22=pd.read_csv(r'F:\dm\1 - Copy\Manipur.csv')
print (df22)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953             0                0.02                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Neg                 Nil                   Nil
# 4       5.0     1957           Neg                 Neg                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL         2.349               3.891                 1.268
# 65      NaN  Average         0.053                0.09                 0.033
# 66      NaN  Maximum         0.116                0.73                  0.08
# 67      NaN   (Year)         -2002               -1989                 -1989
#
# ...

# %%
import pandas as pd
df23=pd.read_csv(r'F:\dm\1 - Copy\Meghalaya.csv')
print (df23)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016         0.003               0.124                 0.003
# 64      NaN    TOTAL         0.268               6.647                 0.253
# 65      NaN  Average         0.009               0.196                 0.009
# 66      NaN  Maximum         0.095                4.77                 0.095
# 67      NaN   (Year)          1987                1983                  1987
#
# ...

# %%
import pandas as pd
df24=pd.read_csv(r'F:\dm\1 - Copy\Mizoram.csv')
print (df24)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL         0.732               0.086                 0.233
# 65      NaN  Average         0.043               0.005                 0.014
# 66      NaN  Maximum         0.541               0.053                 0.189
# 67      NaN   (Year)          1993                1976                  2015
#
# ...

# %%
import pandas as pd
df25=pd.read_csv(r'F:\dm\1 - Copy\Nagaland.csv')
print (df25)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL         0.021               0.376                 0.017
# 65      NaN  Average         0.001                0.02                 0.001
# 66      NaN  Maximum         0.009               0.176                 0.009
# 67      NaN   (Year)         -1993               -2005                 -1993
#
# ...

# %%
import pandas as pd
df26=pd.read_csv(r'F:\dm\1 - Copy\Odisha.csv')
print (df26)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955          0.66                   2                  0.41
# 3       4.0     1956          0.33                 0.9                  0.09
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016         0.009               0.015                   NaN
# 64      NaN    TOTAL        29.192             158.974                20.474
# 65      NaN  Average         0.531                2.89                 0.379
# 66      NaN  Maximum          3.97                 9.8                  3.97
# 67      NaN   (Year)          2014               -1990                  2014
#
# ...

# %%
import pandas as pd
df27=pd.read_csv(r'F:\dm\1 - Copy\Puducherry.csv')
print (df27)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953             0                   0                     0
# 1       2.0     1954             0                   0                     0
# 2       3.0     1955             0                   0                     0
# 3       4.0     1956             0                   0                     0
# 4       5.0     1957             0                   0                     0
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL         0.119               0.602                 0.153
# 65      NaN  Average         0.002               0.012                 0.003
# 66      NaN  Maximum          0.05                0.42                 0.022
# 67      NaN   (Year)         -1977               -1977                 -2008
#
# ...

# %%
import pandas as pd
df28=pd.read_csv(r'F:\dm\1 - Copy\Punjab.csv')
print (df28)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Neg                 Neg                   Neg
# 1       2.0     1954          0.01                   0                  0.01
# 2       3.0     1955          0.92                 Nil                  0.92
# 3       4.0     1956          0.06                 Nil                  0.06
# 4       5.0     1957          0.08                 Nil                  0.08
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016         0.001                   0                 0.001
# 64      NaN    TOTAL        17.819              29.846                14.314
# 65      NaN  Average         0.343               0.649                  0.27
# 66      NaN  Maximum          2.79                 4.3                  2.79
# 67      NaN   (Year)         -1988               -1988                 -1988
#
# ...

# %%
import pandas as pd
df29=pd.read_csv(r'F:\dm\1 - Copy\Rajasthan.csv')
print (df29)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016         0.884               4.381                 0.796
# 64      NaN    TOTAL        18.558              46.255                11.174
# 65      NaN  Average         0.344               0.984                 0.233
# 66      NaN  Maximum          3.26                7.99                  3.09
# 67      NaN   (Year)          1977                1977                  1977
#
# ...

# %%
import pandas as pd
df30=pd.read_csv(r'F:\dm\1 - Copy\Sikkim.csv')
print (df30)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Nil                 Nil                   Nil
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL         1.821               0.935                 1.241
# 65      NaN  Average         0.076               0.033                 0.054
# 66      NaN  Maximum          1.17                0.31                   0.6
# 67      NaN   (Year)          2000                2012                  2000
#
# ...

# %%
import pandas as pd
df31=pd.read_csv(r'F:\dm\1 - Copy\Tamil Nadu.csv')
print (df31)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954           Nil                 Nil                   Nil
# 2       3.0     1955           Nil                 Nil                   Nil
# 3       4.0     1956           Neg                 Nil                   Neg
# 4       5.0     1957          0.03                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL          5.51              55.836                 2.324
# 65      NaN  Average         0.167               1.801                 0.073
# 66      NaN  Maximum         1.466               29.93                 0.383
# 67      NaN   (Year)          2010                1973                  2015
#
# ...

# %%
import pandas as pd
df32=pd.read_csv(r'F:\dm\1 - Copy\Tripura.csv')
print (df32)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Nil
# 1       2.0     1954          0.01                0.05                   Neg
# 2       3.0     1955          0.01                 0.1                   Neg
# 3       4.0     1956          0.03                0.11                   Neg
# 4       5.0     1957           Nil                 Nil                   Nil
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016         0.037               0.091                 0.019
# 64      NaN    TOTAL         1.472               6.404                  0.47
# 65      NaN  Average         0.031               0.133                 0.011
# 66      NaN  Maximum          0.33                 0.7                 0.053
# 67      NaN   (Year)          1963                1984                  1993
#
# ...

# %%
import pandas as pd
df33=pd.read_csv(r'F:\dm\1 - Copy\Uttar Pradesh.csv')
print (df33)
# Out:
#     Sl. No.     Year  Area affected  Population affected  \
# 0       1.0     1953          0.910               14.370
# 1       2.0     1954          1.350                3.400
# 2       3.0     1955          4.130               14.000
# 3       4.0     1956          2.500                8.600
# 4       5.0     1957          1.700                4.190
# ..      ...      ...            ...                  ...
# 63     64.0     2016          0.569                2.032
# 64      NaN    Total        103.942              413.985
# 65      NaN  Average          1.650                6.469
# 66      NaN  Maximum          7.340               30.350
# 67      NaN   (Year)       1978.000             1980.000
#
#     Damage to Crops(area)  Damage to Crops(value)  Damage to Houses(number)  \
# 0                   0.000                  10.820                     80443
# 1                   0.740                   6.820                     19550
# ...

# %%
import pandas as pd
df34=pd.read_csv(r'F:\dm\1 - Copy\Uttarakhand.csv')
print (df34)
# Out:
#     Sl. No.     Year  Area affected Population affected  \
# 0       1.0     1953          0.910               14.37
# 1       2.0     1954          1.350                 3.4
# 2       3.0     1955          4.130                  14
# 3       4.0     1956          2.500                 8.6
# 4       5.0     1957          1.700                4.19
# ..      ...      ...            ...                 ...
# 63     64.0     2016          0.010                 NaN
# 64      NaN    TOTAL          0.072               0.156
# 65      NaN  Average          0.005               0.012
# 66      NaN  Maximum          0.059               0.109
# 67      NaN   (Year)      -2013.000               -2013
#
#     Damage to Crops(area)  Damage to Crops(value)  Damage to Houses(number)  \
# 0                   0.000                  10.820                     80443
# 1                   0.740                   6.820                     19550
# ...

# %%
import pandas as pd
df35=pd.read_csv(r'F:\dm\1 - Copy\West Bengal.csv')
print (df35)
# Out:
#     Sl. No.     Year Area affected Population affected Damage to Crops(area)  \
# 0       1.0     1953           Nil                 Nil                   Neg
# 1       2.0     1954          0.42                 Nil                   Neg
# 2       3.0     1955          0.35                 Nil                   Neg
# 3       4.0     1956          2.65                 0.9                   0.4
# 4       5.0     1957          1.16                 0.1                   Neg
# ..      ...      ...           ...                 ...                   ...
# 63     64.0     2016           NaN                 NaN                   NaN
# 64      NaN    TOTAL        49.537             244.227                18.491
# 65      NaN  Average         0.799                4.07                 0.313
# 66      NaN  Maximum          3.08                21.8                  2.49
# 67      NaN   (Year)         -1978               -2000                 -2007
#
# ...
